# %%
# add for tensorboard code
from __future__ import absolute_import, division, print_function, unicode_literals
import argparse
import json
from tensorflow.python.lib.io import file_io

# origin fairing code
import tensorflow as tf
import os

class MyFashionMnist(object):
  def train(self):
           
    print("TensorFlow version: ", tf.__version__)

    mnist = tf.keras.datasets.mnist

    (x_train, y_train), (x_test, y_test) = mnist.load_data()
    x_train, x_test = x_train / 255.0, x_test / 255.0

    model = tf.keras.models.Sequential([
        tf.keras.layers.Flatten(input_shape=(28, 28)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    model.summary()

    print("Training...")
    
    model.fit(x_train, y_train, epochs=3, validation_split=0.2 ) 
    
    score = model.evaluate(x_test, y_test, batch_size=128, verbose=0)
    print('Test accuracy: ', score[1])

if __name__ == '__main__':
    if os.getenv('FAIRING_RUNTIME', None) is None:
        from kubeflow import fairing
        from kubeflow.fairing.kubernetes import utils as k8s_utils
        
        DOCKER_REGISTRY = 'kubeflow-registry.default.svc.cluster.local:30000'   # 프라이빗 레지스트리

        fairing.config.set_builder(
            'append',
            image_name='tensorboard-job', # here not fairing job but katib job
            base_image='brightfly/kubeflow-jupyter-lab:tf2.0-cpu',
            registry=DOCKER_REGISTRY, 
            push=True
        )
        # cpu 1, memory 5GiB
        fairing.config.set_deployer('job',
                                    namespace='admin', # here
                                    pod_spec_mutators=[
                                        k8s_utils.get_resource_mutator(cpu=1,  # here
                                                                       memory=5)]
                                   )
        fairing.config.run()
    else:
        remote_train = MyFashionMnist()
        remote_train.train()
# Out:
# [I 201010 12:58:33 config:123] Using preprocessor: <kubeflow.fairing.preprocessors.converted_notebook.ConvertNotebookPreprocessor object at 0x7f9c64399358>
# [I 201010 12:58:33 config:125] Using builder: <kubeflow.fairing.builders.append.append.AppendBuilder object at 0x7f9c2826bb00>
# [I 201010 12:58:33 config:127] Using deployer: <kubeflow.fairing.builders.append.append.AppendBuilder object at 0x7f9c2826bb00>
# [W 201010 12:58:33 append:50] Building image using Append builder...
# [I 201010 12:58:33 base:105] Creating docker context: /tmp/fairing_context_cfhkzgmk
# [I 201010 12:58:33 converted_notebook:127] Converting 02-train-fairing.ipynb to 02-train-fairing.py
# [I 201010 12:58:33 docker_creds_:234] Loading Docker credentials for repository 'brightfly/kubeflow-jupyter-lab:tf2.0-cpu'
# [W 201010 12:58:35 append:54] Image successfully built in 2.399962108996988s.
# [W 201010 12:58:35 append:94] Pushing image kubeflow-registry.default.svc.cluster.local:30000/tensorboard-job:2F310C08...
# [I 201010 12:58:35 docker_creds_:234] Loading Docker credentials for repository 'kubeflow-registry.default.svc.cluster.local:30000/tensorboard-job:2F310C08'
# [W 201010 12:58:35 append:81] Uploading kubeflow-registry.default.svc.cluster.local:30000/tensorboard-job:2F310C08
# [I 201010 12:58:35 docker_session_:280] Layer sha256:6ac505cbabeccba798e608e1bb80ae66f497c2c856733800e1db060e3c875917 exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:7acbfba21e38804c20c4da292d2f99d88d317b83440fb2f3de0a620edf2b9595 exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:069de100aaecb1299b09dab29a4eb39a2ca6a5f8c0a033b65ff0e15e9ea39a24 exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:d83811f270d56d34a208f721f3dbf1b9242d1900ad8981fc7071339681998a31 exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:872efc07c3d848e0f55b7cbce9866a8dea7b76d8c1f131801934ea0d856b15c5 exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:1c60aaf19cc4c142934f390281975f61956475c205b5895711f839a91f927779 exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:c2f81144f815902f9c6e6f7883068544e35924f0efe2275bc41c3d0c558f394c exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:af228bb15b867acbee0d6df28dbb42a8218948fdde64833bd021a255a99a2690 exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:8e7d3ffcd500d3ed0b2ee2449a36a44601b8e282cc6d541ab93f1189d4a2cf93 exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:485ea80d093de507a5ccd36effaf8dad03b67a1063edbd427fedfe667c9155bc exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:50f1fe304a9431ea025aa6ee5e8e45826fa62640a83e55be8bd3c227119cbcd2 exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:66257906239d377cd700c566b27f12895ccefcd8d95eae7377f600208151d8e0 exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:5667fdb72017d1fb364744ca1abf7b6f3bbe9c98c3786f294a461c2866db69ab exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:d0d480fe0d0ab233a90471379d9d3789d4153ad4611d101cfefdfc0c507d9356 exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:fd781ca227d0199735cceb67afa81e2a073b5ef5867ca6e96ad46e002a03252a exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:fb9676c4102241f220b864e98c53676e27c407c6ecfbb13c2cbc1fa4de8f1811 exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:7fc152dfb3a6b5c9a436b49ff6cd72ed7eb5f1fd349128b50ee04c3c5c2355fb exists, skipping
# [I 201010 12:58:35 docker_session_:284] Layer sha256:509319361ccc631a164953617c5851b9b74e1cee8b0a7ef89f0aa327a0837247 pushed.
# [I 201010 12:58:35 docker_session_:280] Layer sha256:ee671aafb583e2321880e275c94d49a49185006730e871435cd851f42d2a775d exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:d846ead9aa38bc0d35dd500ada5349fe42efb96c89db08b8abcb9ad949332c2a exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:8f64ecfab6c102a62dd5d912d96113603663ad8b436701bf2dbd1aa9630882e7 exists, skipping
# [I 201010 12:58:35 docker_session_:280] Layer sha256:df80607e3e38dc3f117e967a36620c42f791afc9ca0568900d13d84c1e3a38bb exists, skipping
# [I 201010 12:58:35 docker_session_:284] Layer sha256:ad7c41123c719817c138356d97a2a52aba167c8ad1333150fde286be0c4ed08c pushed.
# [I 201010 12:58:35 docker_session_:334] Finished upload of: kubeflow-registry.default.svc.cluster.local:30000/tensorboard-job:2F310C08
# [W 201010 12:58:35 append:99] Pushed image kubeflow-registry.default.svc.cluster.local:30000/tensorboard-job:2F310C08 in 0.1941873290015792s.
# [W 201010 12:58:35 job:90] The job fairing-job-7bq52 launched.
# [W 201010 12:58:35 manager:227] Waiting for fairing-job-7bq52-9flvp to start...
# [W 201010 12:58:35 manager:227] Waiting for fairing-job-7bq52-9flvp to start...
# [W 201010 12:58:35 manager:227] Waiting for fairing-job-7bq52-9flvp to start...
# [W 201010 12:58:36 manager:227] Waiting for fairing-job-7bq52-9flvp to start...
# [I 201010 12:58:37 manager:233] Pod started running True
# TensorFlow version:  2.0.0
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 2020-10-10 12:58:39.870425: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-10-10 12:58:39.875724: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-10-10 12:58:39.876147: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3d25e40 executing computations on platform Host. Devices:
# 2020-10-10 12:58:39.876180: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________
# Training...
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/3
#  2880/48000 [>.............................] - ETA: 15s - loss: 1.0247 - accuracy: 0.7048
#  6656/48000 [===>..........................] - ETA: 9s - loss: 0.7147 -- accuracy: 0.781
# 10432/48000 [=====>........................] - ETA: 8s - loss: 0.6015 - accuracy: 0.82
# 13632/48000 [=======>......................] - ETA: 6s - loss: 0.5291 - accuracy: 0.84
# 17440/48000 [=========>....................] - ETA: 5s - loss: 0.4841 - accuracy: 0.86
# 21344/48000 [============>.................] - ETA: 4s - loss: 0.4501 - accuracy: 0.87
# 25248/48000 [==============>...............] - ETA: 4s - loss: 0.4245 - accuracy: 0.87
# 29120/48000 [================>.............] - ETA: 3s - loss: 0.4021 - accuracy: 0.88
# 32384/48000 [===================>..........] - ETA: 2s - loss: 0.3810 - accuracy: 0.890
# 36288/48000 [=====================>........] - ETA: 1s - loss: 0.3635 - accuracy: 0.895
# 40192/48000 [========================>.....] - ETA: 1s - loss: 0.3496 - accuracy: 0.89
# 44064/48000 [==========================>...] - ETA: 0s - loss: 0.3378 - accuracy: 0.90
# 47936/48000 [============================>.] - ETA: 0s - loss: 0.3270 - accuracy: 0.90
# 48000/48000 [==============================] - 9s 189us/sample - loss: 0.3252 - accuracy: 0.9056 - val_loss: 0.1528 - val_accuracy: 0.9559
# Epoch 2/3
#  2912/48000 [>.............................] - ETA: 7s - loss: 0.1777 - accuracy: 0.94
#  6816/48000 [===>..........................] - ETA: 6s - loss: 0.1677 - accuracy: 0.95
# 10656/48000 [=====>........................] - ETA: 5s - loss: 0.1685 - accuracy: 0.95
# 14496/48000 [========>.....................] - ETA: 5s - loss: 0.1647 - accuracy: 0.95
# 17728/48000 [==========>...................] - ETA: 4s - loss: 0.1608 - accuracy: 0.953
# 21568/48000 [============>.................] - ETA: 4s - loss: 0.1590 - accuracy: 0.953
# 25440/48000 [==============>...............] - ETA: 3s - loss: 0.1581 - accuracy: 0.954
# 29344/48000 [=================>............] - ETA: 3s - loss: 0.1585 - accuracy: 0.95
# 33216/48000 [===================>..........] - ETA: 2s - loss: 0.1565 - accuracy: 0.95
# 36448/48000 [=====================>........] - ETA: 1s - loss: 0.1554 - accuracy: 0.95
# 40320/48000 [========================>.....] - ETA: 1s - loss: 0.1554 - accuracy: 0.95
# 44256/48000 [==========================>...] - ETA: 0s - loss: 0.1546 - accuracy: 0.95
# 48000/48000 [============================>.] - ETA: 0s - loss: 0.1535 - accuracy: 0.95
# =======] - 8s 177us/sample - loss: 0.1538 - accuracy: 0.9549 - val_loss: 0.1152 - val_accuracy: 0.9656
# Epoch 3/3
#  3040/48000 [>.............................] - ETA: 7s - loss: 0.1054 - accuracy: 0.96
#  6848/48000 [===>..........................] - ETA: 6s - loss: 0.1093 - accuracy: 0.96
# 10752/48000 [=====>........................] - ETA: 5s - loss: 0.1116 - accuracy: 0.96
# 14592/48000 [========>.....................] - ETA: 5s - loss: 0.1128 - accuracy: 0.96
# 17824/48000 [==========>...................] - ETA: 4s - loss: 0.1150 - accuracy: 0.964
# 21728/48000 [============>.................] - ETA: 4s - loss: 0.1143 - accuracy: 0.965
# 25600/48000 [===============>..............] - ETA: 3s - loss: 0.1151 - accuracy: 0.964
# 29472/48000 [=================>............] - ETA: 2s - loss: 0.1156 - accuracy: 0.96
# 33344/48000 [===================>..........] - ETA: 2s - loss: 0.1164 - accuracy: 0.96
# 36608/48000 [=====================>........] - ETA: 1s - loss: 0.1148 - accuracy: 0.96
# 40448/48000 [========================>.....] - ETA: 1s - loss: 0.1153 - accuracy: 0.96
# 44384/48000 [==========================>...] - ETA: 0s - loss: 0.1154 - accuracy: 0.96
# 48000/48000 [============================>.] - ETA: 0s - loss: 0.1144 - accuracy: 0.96
# =======] - 8s 176us/sample - loss: 0.1144 - accuracy: 0.9654 - val_loss: 0.0931 - val_accuracy: 0.9732
# Test accuracy:  0.9723
# [W 201010 12:59:08 job:162] Cleaning up job fairing-job-7bq52...
