# %%
# add for tensorboard code
from __future__ import absolute_import, division, print_function, unicode_literals
import argparse
import json
from tensorflow.python.lib.io import file_io

# origin fairing code
import tensorflow as tf
import os
from tensorflow.python.keras.callbacks import Callback

class MyFashionMnist(object):
  def train(self):
    
    # argument
    parser = argparse.ArgumentParser()
    parser.add_argument('--tb_log_dir', default='./data/logs', type=str)
    args = parser.parse_args()
    tb_log_dir = args.tb_log_dir

    print("TensorFlow version: ", tf.__version__)

    mnist = tf.keras.datasets.mnist

    (x_train, y_train), (x_test, y_test) = mnist.load_data()
    x_train, x_test = x_train / 255.0, x_test / 255.0

    model = tf.keras.models.Sequential([
        tf.keras.layers.Flatten(input_shape=(28, 28)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    model.summary()

    callbacks = [tf.keras.callbacks.TensorBoard(log_dir=tb_log_dir)]
    print("Training...")
    
    model.fit(x_train, y_train, epochs=3, validation_split=0.2, callbacks=callbacks) # here epochs
    
    score = model.evaluate(x_test, y_test, batch_size=128, verbose=0)
    print('Test accuracy: ', score[1])

    # tensorboard
    metadata = {
        'outputs': [{
            'type': 'tensorboard',
            'source': tb_log_dir,
        }]
    }
    
    with file_io.FileIO('/mlpipeline-ui-metadata.json', 'w') as f:
        json.dump(metadata, f)

if __name__ == '__main__':
    if os.getenv('FAIRING_RUNTIME', None) is None:
        from kubeflow import fairing
        from kubeflow.fairing.kubernetes import utils as k8s_utils
        
        DOCKER_REGISTRY = 'kubeflow-registry.default.svc.cluster.local:30000'   # 프라이빗 레지스트리

        fairing.config.set_builder(
            'append',
            image_name='tensorboard-job', # here not fairing job but katib job
            base_image='brightfly/kubeflow-jupyter-lab:tf2.0-cpu',
            registry=DOCKER_REGISTRY, 
            push=True
        )
        # cpu 1, memory 5GiB
        fairing.config.set_deployer('job',
                                    namespace='admin', # here
                                    pod_spec_mutators=[
                                        k8s_utils.get_resource_mutator(cpu=1,  # here
                                                                       memory=5)]
         
                                   )
        fairing.config.run()
    else:
        remote_train = MyFashionMnist()
        remote_train.train()
# Out:
# [I 201010 14:21:48 config:123] Using preprocessor: <kubeflow.fairing.preprocessors.converted_notebook.ConvertNotebookPreprocessor object at 0x7fd7a42bc320>
# [I 201010 14:21:48 config:125] Using builder: <kubeflow.fairing.builders.append.append.AppendBuilder object at 0x7fd76a1997b8>
# [I 201010 14:21:48 config:127] Using deployer: <kubeflow.fairing.builders.append.append.AppendBuilder object at 0x7fd76a1997b8>
# [W 201010 14:21:48 append:50] Building image using Append builder...
# [I 201010 14:21:48 base:105] Creating docker context: /tmp/fairing_context_oefwh9p2
# [I 201010 14:21:48 converted_notebook:127] Converting 14-tensorboard-fairing.ipynb to 14-tensorboard-fairing.py
# [I 201010 14:21:49 docker_creds_:234] Loading Docker credentials for repository 'brightfly/kubeflow-jupyter-lab:tf2.0-cpu'
# [W 201010 14:21:51 append:54] Image successfully built in 2.368875150998065s.
# [W 201010 14:21:51 append:94] Pushing image kubeflow-registry.default.svc.cluster.local:30000/tensorboard-job:25481222...
# [I 201010 14:21:51 docker_creds_:234] Loading Docker credentials for repository 'kubeflow-registry.default.svc.cluster.local:30000/tensorboard-job:25481222'
# [W 201010 14:21:51 append:81] Uploading kubeflow-registry.default.svc.cluster.local:30000/tensorboard-job:25481222
# [I 201010 14:21:51 docker_session_:280] Layer sha256:af228bb15b867acbee0d6df28dbb42a8218948fdde64833bd021a255a99a2690 exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:d846ead9aa38bc0d35dd500ada5349fe42efb96c89db08b8abcb9ad949332c2a exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:fd781ca227d0199735cceb67afa81e2a073b5ef5867ca6e96ad46e002a03252a exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:7fc152dfb3a6b5c9a436b49ff6cd72ed7eb5f1fd349128b50ee04c3c5c2355fb exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:ee671aafb583e2321880e275c94d49a49185006730e871435cd851f42d2a775d exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:66257906239d377cd700c566b27f12895ccefcd8d95eae7377f600208151d8e0 exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:d83811f270d56d34a208f721f3dbf1b9242d1900ad8981fc7071339681998a31 exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:5667fdb72017d1fb364744ca1abf7b6f3bbe9c98c3786f294a461c2866db69ab exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:50f1fe304a9431ea025aa6ee5e8e45826fa62640a83e55be8bd3c227119cbcd2 exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:485ea80d093de507a5ccd36effaf8dad03b67a1063edbd427fedfe667c9155bc exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:7acbfba21e38804c20c4da292d2f99d88d317b83440fb2f3de0a620edf2b9595 exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:8e7d3ffcd500d3ed0b2ee2449a36a44601b8e282cc6d541ab93f1189d4a2cf93 exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:6ac505cbabeccba798e608e1bb80ae66f497c2c856733800e1db060e3c875917 exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:872efc07c3d848e0f55b7cbce9866a8dea7b76d8c1f131801934ea0d856b15c5 exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:fb9676c4102241f220b864e98c53676e27c407c6ecfbb13c2cbc1fa4de8f1811 exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:1c60aaf19cc4c142934f390281975f61956475c205b5895711f839a91f927779 exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:c2f81144f815902f9c6e6f7883068544e35924f0efe2275bc41c3d0c558f394c exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:8f64ecfab6c102a62dd5d912d96113603663ad8b436701bf2dbd1aa9630882e7 exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:069de100aaecb1299b09dab29a4eb39a2ca6a5f8c0a033b65ff0e15e9ea39a24 exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:df80607e3e38dc3f117e967a36620c42f791afc9ca0568900d13d84c1e3a38bb exists, skipping
# [I 201010 14:21:51 docker_session_:280] Layer sha256:d0d480fe0d0ab233a90471379d9d3789d4153ad4611d101cfefdfc0c507d9356 exists, skipping
# [I 201010 14:21:51 docker_session_:284] Layer sha256:4cd468b57bc90f13eb0077044e2df9d956c7d828538f77669011f4906ab1d9ef pushed.
# [I 201010 14:21:51 docker_session_:284] Layer sha256:6f260eed83382b11793eab9ca10f1fd115c81852fe13a6448e4e95a452934d66 pushed.
# [I 201010 14:21:51 docker_session_:334] Finished upload of: kubeflow-registry.default.svc.cluster.local:30000/tensorboard-job:25481222
# [W 201010 14:21:51 append:99] Pushed image kubeflow-registry.default.svc.cluster.local:30000/tensorboard-job:25481222 in 0.14837784100018325s.
# [W 201010 14:21:51 job:90] The job fairing-job-vhmfh launched.
# [W 201010 14:21:51 manager:227] Waiting for fairing-job-vhmfh-6lh8b to start...
# [W 201010 14:21:51 manager:227] Waiting for fairing-job-vhmfh-6lh8b to start...
# [W 201010 14:21:51 manager:227] Waiting for fairing-job-vhmfh-6lh8b to start...
# [W 201010 14:21:52 manager:227] Waiting for fairing-job-vhmfh-6lh8b to start...
# [I 201010 14:21:53 manager:233] Pod started running True
# TensorFlow version:  2.0.0
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 2020-10-10 14:21:55.586646: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-10-10 14:21:55.592449: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-10-10 14:21:55.592857: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x53cbf50 executing computations on platform Host. Devices:
# 2020-10-10 14:21:55.592897: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2020-10-10 14:21:56.481670: I tensorflow/core/profiler/lib/profiler_session.cc:184] Profiler session started.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________
# Training...
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/3
#  2848/48000 [>.............................] - ETA: 14s - loss: 1.0286 - accuracy: 0.70223
#  6720/48000 [===>..........................] - ETA: 9s - loss: 0.6999 - accuracy: 0.7897
# 10688/48000 [=====>........................] - ETA: 7s - loss: 0.5936 - accuracy: 0.83
# 13984/48000 [=======>......................] - ETA: 6s - loss: 0.5164 - accuracy: 0.85
# 17920/48000 [==========>...................] - ETA: 5s - loss: 0.4726 - accuracy: 0.86
# 21920/48000 [============>.................] - ETA: 4s - loss: 0.4379 - accuracy: 0.87
# 25888/48000 [===============>..............] - ETA: 3s - loss: 0.4139 - accuracy: 0.88
# 29824/48000 [=================>............] - ETA: 3s - loss: 0.3902 - accuracy: 0.88
